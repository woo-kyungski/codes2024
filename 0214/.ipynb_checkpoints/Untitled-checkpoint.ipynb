# %%
input_a1 = int(input('a1 입력: '))
input_D = int(input('D 입력: '))
input_N = int(input('N 입력: '))

value_n = 0
nn = 1
while n <= input_N:
    
    if n == 1:
        value_n = input_a1
        print('{}번째 항의 값: {}'.format(nn, value_n))
        nn += 1
        continue

    else:
        value_n += input_D
        print(('{}번째 항의 값: {}'.format(nn, value_n))
        nn += 1
              

print(('{}번째 항의 값: {}'.format(nn, value_n))
# Out:
#   Cell In[5], line 18
#     nn += 1
#     ^
# SyntaxError: invalid syntax
