# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-3, 2, 100)
y = 3 * x**2 + 2

# %%
x
# Out:
# array([-3.        , -2.94949495, -2.8989899 , -2.84848485, -2.7979798 ,
#        -2.74747475, -2.6969697 , -2.64646465, -2.5959596 , -2.54545455,
#        -2.49494949, -2.44444444, -2.39393939, -2.34343434, -2.29292929,
#        -2.24242424, -2.19191919, -2.14141414, -2.09090909, -2.04040404,
#        -1.98989899, -1.93939394, -1.88888889, -1.83838384, -1.78787879,
#        -1.73737374, -1.68686869, -1.63636364, -1.58585859, -1.53535354,
#        -1.48484848, -1.43434343, -1.38383838, -1.33333333, -1.28282828,
#        -1.23232323, -1.18181818, -1.13131313, -1.08080808, -1.03030303,
#        -0.97979798, -0.92929293, -0.87878788, -0.82828283, -0.77777778,
#        -0.72727273, -0.67676768, -0.62626263, -0.57575758, -0.52525253,
#        -0.47474747, -0.42424242, -0.37373737, -0.32323232, -0.27272727,
#        -0.22222222, -0.17171717, -0.12121212, -0.07070707, -0.02020202,
#         0.03030303,  0.08080808,  0.13131313,  0.18181818,  0.23232323,
#         0.28282828,  0.33333333,  0.38383838,  0.43434343,  0.48484848,
#         0.53535354,  0.58585859,  0.63636364,  0.68686869,  0.73737374,
#         0.78787879,  0.83838384,  0.88888889,  0.93939394,  0.98989899,
#         1.04040404,  1.09090909,  1.14141414,  1.19191919,  1.24242424,
#         1.29292929,  1.34343434,  1.39393939,  1.44444444,  1.49494949,
#         1.54545455,  1.5959596 ,  1.64646465,  1.6969697 ,  1.74747475,
#         1.7979798 ,  1.84848485,  1.8989899 ,  1.94949495,  2.        ])

# %%
y
# Out:
# array([29.        , 28.09856137, 27.2124273 , 26.3415978 , 25.48607285,
#        24.64585246, 23.82093664, 23.01132537, 22.21701867, 21.43801653,
#        20.67431895, 19.92592593, 19.19283747, 18.47505357, 17.77257423,
#        17.08539945, 16.41352923, 15.75696358, 15.11570248, 14.48974594,
#        13.87909397, 13.28374656, 12.7037037 , 12.13896541, 11.58953168,
#        11.05540251, 10.5365779 , 10.03305785,  9.54484236,  9.07193144,
#         8.61432507,  8.17202326,  7.74502602,  7.33333333,  6.93694521,
#         6.55586165,  6.19008264,  5.8396082 ,  5.50443832,  5.184573  ,
#         4.88001224,  4.59075605,  4.31680441,  4.05815733,  3.81481481,
#         3.58677686,  3.37404346,  3.17661463,  2.99449036,  2.82767065,
#         2.67615549,  2.5399449 ,  2.41903887,  2.3134374 ,  2.2231405 ,
#         2.14814815,  2.08846036,  2.04407713,  2.01499847,  2.00122436,
#         2.00275482,  2.01958984,  2.05172942,  2.09917355,  2.16192225,
#         2.23997551,  2.33333333,  2.44199571,  2.56596266,  2.70523416,
#         2.85981022,  3.02969085,  3.21487603,  3.41536578,  3.63116009,
#         3.86225895,  4.10866238,  4.37037037,  4.64738292,  4.93970003,
#         5.2473217 ,  5.57024793,  5.90847873,  6.26201408,  6.63085399,
#         7.01499847,  7.41444751,  7.8292011 ,  8.25925926,  8.70462198,
#         9.16528926,  9.6412611 , 10.1325375 , 10.63911846, 11.16100398,
#        11.69819406, 12.25068871, 12.81848791, 13.40159167, 14.        ])

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y)
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$3x^2 + 2$')
plt.show()

# %%
x = np.linspace(-5,5, 100)
y1 = 3*x**2 + 2
y2 = 3*(x+1)**2 + 2

# %%
y1
# Out:
# array([77.        , 74.00030609, 71.06183043, 68.184573  , 65.36853382,
#        62.61371289, 59.92011019, 57.28772574, 54.71655953, 52.20661157,
#        49.75788185, 47.37037037, 45.04407713, 42.77900214, 40.57514539,
#        38.43250689, 36.35108662, 34.3308846 , 32.37190083, 30.47413529,
#        28.637588  , 26.86225895, 25.14814815, 23.49525559, 21.90358127,
#        20.37312519, 18.90388736, 17.49586777, 16.14906642, 14.86348332,
#        13.63911846, 12.47597184, 11.37404346, 10.33333333,  9.35384144,
#         8.4355678 ,  7.5785124 ,  6.78267524,  6.04805632,  5.37465565,
#         4.76247322,  4.21150903,  3.72176309,  3.29323538,  2.92592593,
#         2.61983471,  2.37496174,  2.19130701,  2.06887052,  2.00765228,
#         2.00765228,  2.06887052,  2.19130701,  2.37496174,  2.61983471,
#         2.92592593,  3.29323538,  3.72176309,  4.21150903,  4.76247322,
#         5.37465565,  6.04805632,  6.78267524,  7.5785124 ,  8.4355678 ,
#         9.35384144, 10.33333333, 11.37404346, 12.47597184, 13.63911846,
#        14.86348332, 16.14906642, 17.49586777, 18.90388736, 20.37312519,
#        21.90358127, 23.49525559, 25.14814815, 26.86225895, 28.637588  ,
#        30.47413529, 32.37190083, 34.3308846 , 36.35108662, 38.43250689,
#        40.57514539, 42.77900214, 45.04407713, 47.37037037, 49.75788185,
#        52.20661157, 54.71655953, 57.28772574, 59.92011019, 62.61371289,
#        65.36853382, 68.184573  , 71.06183043, 74.00030609, 77.        ])

# %%
plt.figure(figsize=(12, 8))
plt.plot(x, y1, ls='dashed', label='$y=3x^2 +2$')
plt.plot(x, y2, label='$y=3(x+1)^2 +2$')
plt.legend(fontsize=15)
plt.grid()
plt.xlabel('$x$',fontsize=25)
plt.ylabel('$y$',fontsize=25)
plt.show()

# %%
x = np.linspace(-1, 2, 100)
a11, a12, a13 = 2, 3, 4
y11, y12, y13 = a11**x, a12**x, a13**x

a21, a22, a23 = 1/2, 1/3, 1/4
y21, y22, y23 = a21**x, a22**x, a23**x

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6)) #1행 2열

ax[0].plot(x, y11, color='k', label=r'$2^x$')
ax[0].plot(x, y12, '--', color='k', label=r'$3^x$')
ax[0].plot(x, y13, ':', color='k', label=r'$4^x$')
ax[0].legend(fontsize=20)

ax[1].plot(x, y21, color='k', label=r'$(1/2)^x$')
ax[1].plot(x, y22, '--', color='k', label=r'$(1/3)^x$')
ax[1].plot(x, y23, ':', color='k', label=r'$(1/4)^x$')
ax[1].legend(fontsize=20)

plt.show()

# %%
len(ax)
# Out:
# 2

# %%
x = np.linspace(0,  10)

plt.figure(figsize=(6,6))
plt.plot(x, x**2, '--', color='k', label=r'$x^2$')
plt.plot(x, 2**x, color='k', label=r'$2^x$')

plt.legend(loc='center left', fontsize=25)
plt.xlabel('$x$',fontsize=25)
plt.ylabel('$y$',fontsize=25)

plt.show()

# %%
x = np.array([10,100, 1000, 10000, 100000, 1000000, 10000000])

(1 + 1/x)**x
# Out:
# array([2.59374246, 2.70481383, 2.71692393, 2.71814593, 2.71826824,
#        2.71828047, 2.71828169])

# %%
def log(x, base):
    return np.log(x) / np.log(base)

x1 = np.linspace(0.0001, 5, 1000)
x2 = np.linspace(0.01, 5, 100)

y11, y12 = log(x1, 10), log(x2, np.e)
y21, y22 = log(x1, 10), log(x2, 1/np.e)

# %%
np.exp(1) #e
# Out:
# 2.718281828459045

# %%
np.log(np.exp(1)) #np.log : 밑수가 e인 로그
# Out:
# 1.0

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6)) #1행 2열

ax[0].plot(x1, y11, color='k', label=r'$\log_{10} x$')
ax[0].plot(x2, y12, '--', color='k', label=r'$\log_{e} x$')

ax[0].set_xlabel('$x$', fontsize=25)
ax[0].set_ylabel('$y$', fontsize=25)
ax[0].legend(fontsize=20, loc='lower right')

ax[1].plot(x1, y21, color='k', label=r'$\log_{1/10} x$')
ax[1].plot(x2, y22, '--', color='k', label=r'$\log_{1/e} x$')

ax[1].set_xlabel('$x$', fontsize=25)
ax[1].set_ylabel('$y$', fontsize=25)
ax[1].legend(fontsize=20, loc='upper right')

plt.show()
