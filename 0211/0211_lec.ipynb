# %%
input_num = int(input('0보다 큰 정수 입력: '))

for number in range(1, input_num+1):
    if input_num % number == 0:
        print('{}의 약수: {}'.format(input_num, number))
# Out:
# 0보다 큰 정수 입력:  30
# 30의 약수: 1
# 30의 약수: 2
# 30의 약수: 3
# 30의 약수: 5
# 30의 약수: 6
# 30의 약수: 10
# 30의 약수: 15
# 30의 약수: 30

# %%
input_num = int(input('2보다 큰 정수 입력: '))

for number in  range(2, (input_num+1)):
    flag = True
    for n in range(2, number):
        if number % n == 0:
            flag = False
            break

    if(flag):
        print('{} : 소수'.format(number))

    else:
        print('{} : 합성수'.format(number))
# Out:
# 2보다 큰 정수 입력:  30
# 2 : 소수
# 3 : 소수
# 4 : 합성수
# 5 : 소수
# 6 : 합성수
# 7 : 소수
# 8 : 합성수
# 9 : 합성수
# 10 : 합성수
# 11 : 소수
# 12 : 합성수
# 13 : 소수
# 14 : 합성수
# 15 : 합성수
# 16 : 합성수
# 17 : 소수
# 18 : 합성수
# 19 : 소수
# 20 : 합성수
# 21 : 합성수
# 22 : 합성수
# 23 : 소수
# 24 : 합성수
# 25 : 합성수
# 26 : 합성수
# 27 : 합성수
# 28 : 합성수
# 29 : 소수
# 30 : 합성수

# %%
input_num = int(input('1보다 큰 정수 입력: '))

n = 2
while n <= input_num:
    if input_num % n == 0:
        print('소인수: {}'.format(n))
        input_num /= n

    else:
        n += 1
# Out:
# 1보다 큰 정수 입력:  20
# 소인수: 2
# 소인수: 2
# 소인수: 5

# %%
num1 = int(input('1보다 큰 정수 입력: '))
num2 = int(input('1보다 큰 정수 입력: '))
max_num = 0

for i in range(1, ((num1 if num1 >= num2 else num2)+ 1)):
    if num1 % i == 0 and num2 % i ==0:
        print('공약수: {}'.format(i))
        max_num = i

print('최대공약수: {}'.format(max_num))
# Out:
# 1보다 큰 정수 입력:  39
# 1보다 큰 정수 입력:  72
# 공약수: 1
# 공약수: 3
# 최대공약수: 3

# %% [markdown]
# 유클리드 호제법 \
# x, y의 최대 공약수 == y, r(x % y)의 최대공약수

# %%
num1 = int(input('1보다 큰 정수 입력: '))
num2 = int(input('1보다 큰 정수 입력: '))

temp1 = num1
temp2 = num2

while temp2 > 0:
    temp = temp2
    temp2 = temp1 % temp2
    temp1 = temp

print('{}, {}의 최대공약수: {}'.format(num1, num2, temp1))
# Out:
# 1보다 큰 정수 입력:  20
# 1보다 큰 정수 입력:  10
# 20, 10의 최대공약수: 10

# %%
num1 = int(input('1보다 큰 정수 입력: '))
num2 = int(input('1보다 큰 정수 입력: '))
max_num = 0

for i in range(1, ((num1 if num1 >= num2 else num2)+ 1)):
    if num1 % i == 0 and num2 % i ==0:
        print('공약수: {}'.format(i))
        max_num = i

print('최대공약수: {}'.format(max_num))

min_num = (num1  * num2) // max_num
print('최소공배수: {}'.format(min_num))
# Out:
# 1보다 큰 정수 입력:  24
# 1보다 큰 정수 입력:  21
# 공약수: 1
# 공약수: 3
# 최대공약수: 3
# 최소공배수: 168

# %%
d_num = int(input('정수 입력: '))

print('2진수: {}'.format(bin(d_num)))
print('2진수: {}'.format(type(bin(d_num))))
print('2진수: {}'.format(d_num, '#b'))
print('2진수: {}'.format(d_num, 'b'))

print('8진수: {}'.format(oct(d_num)))
print('8진수: {}'.format(type(oct(d_num))))
print('8진수: {}'.format(d_num, '#o'))
print('8진수: {}'.format(d_num, 'o'))

print('16진수: {}'.format(hex(d_num)))
print('16진수: {}'.format(type(hex(d_num))))
print('16진수: {}'.format(d_num, '#x'))
print('16진수: {}'.format(d_num, 'x'))
# Out:
# 정수 입력:  20
# 2진수: 0b10100
# 2진수: <class 'str'>
# 2진수: 20
# 2진수: 20
# 8진수: 0o24
# 8진수: <class 'str'>
# 8진수: 20
# 8진수: 20
# 16진수: 0x14
# 16진수: <class 'str'>
# 16진수: 20
# 16진수: 20

# %%
a= 30
print(format(a, '#o'))
# Out:
# 0o36
