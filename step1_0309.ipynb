# %% [markdown]
# # Step 1 입출력과 사칙연산

# %% [markdown]
# 단계	문제 번호	제목	정보	정답	제출	정답 비율 https://www.acmicpc.net/step/1

# %% [markdown]
# 1	2557	 Hello World	성공	450108	1115776	39.386% https://www.acmicpc.net/problem/2557

# %% [markdown]
#  2	1000	 A+B	다국어	410097	1036240	39.320% https://www.acmicpc.net/problem/1000

# %% [markdown]
# 3	1001	 A-B		288305	421347	69.671% https://www.acmicpc.net/problem/1001

# %% [markdown]
# 4	10998	 A×B		226944	297391	77.167% https://www.acmicpc.net/problem/10998

# %% [markdown]
# 5	1008	 A/B	스페셜 저지	236920	699813	34.575% https://www.acmicpc.net/problem/1008

# %% [markdown]
# 6	10869	 사칙연산		233518	513441	45.603% https://www.acmicpc.net/problem/10869

# %% [markdown]
# 7	10926	 ??!		124529	248465	50.682% https://www.acmicpc.net/problem/10926

# %% [markdown]
# 8	18108	 1998년생인 내가 태국에서는 2541년생?!		112927	176560	64.123% https://www.acmicpc.net/problem/18108

# %% [markdown]
# 9	10430	 나머지		199271	385657	51.982% https://www.acmicpc.net/problem/10430

# %% [markdown]
# 10	2588	 곱셈		176201	375569	46.999% https://www.acmicpc.net/problem/2588

# %%
a = int(input())
b = int(input())
print(a * int(str(b)[-1]))
print(a * int(str(b)[-2]))
print(a * int(str(b)[0]))
print(a * b)
# Out:
#  472
#  385
# 2360
# 3776
# 1416
# 181720

# %% [markdown]
# 11	11382	 꼬마 정민		69462	171761	41.017%  https://www.acmicpc.net/problem/11382

# %% [markdown]
# 12	10171	 고양이	다국어	189957	560896	35.030% https://www.acmicpc.net/problem/10171

# %%
print('\\    /\\')
print(' )  ( \')')
print('(  /  )')
print(' \\(__)|')
# Out:
# \    /\
#  )  ( ')
# (  /  )
#  \(__)|

# %% [markdown]
# 13	10172	 개	다국어	180749	434934	42.441% https://www.acmicpc.net/problem/10172

# %%
print('|\_/|')
print('|q p|   /}')
print('( 0 )""\"\\')
print('|"^"`    |')
print('||_/=\\\__|')
# Out:
# |\_/|
# |q p|   /}
# ( 0 )"""\
# |"^"`    |
# ||_/=\\__|
