# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
pd.read_csv('sample_data/mnist_test.csv')

# %%
pd.read_csv('drive/MyDrive/ds_study/data/data.csv')

# %%
# !ls #하위목록 확인

# %%
# !ls /content/drive/MyDrive/ds_study/data/ #하위목록 확인
