# %%
import pandas as pd
from urllib.request import urlopen, Request
from fake_useragent import UserAgent
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('./data/03. best_sandwiches_list_chicago.csv', index_col=0)
df.tail()
# Out:
#     Rank                    Cafe                Menu  \
# 45    46                Chickpea               Kufta
# 46    47  The Goddess and Grocer  Debbie’s Egg Salad
# 47    48                 Zenwich          Beef Curry
# 48    49         Toni Patisserie       Le Végétarien
# 49    50         Phoebe’s Bakery          The Gatsby
#
#                                                   URL
# 45  https://www.chicagomag.com/Chicago-Magazine/No...
# 46  https://www.chicagomag.com/Chicago-Magazine/No...
# 47  https://www.chicagomag.com/Chicago-Magazine/No...
# 48  https://www.chicagomag.com/Chicago-Magazine/No...
# 49  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df['URL'][0]
# Out:
# 'https://www.chicagomag.com/Chicago-Magazine/November-2012/Best-Sandwiches-in-Chicago-Old-Oak-Tap-BLT/'

# %%
req = Request(df['URL'][0], headers={"user-agent": 'Chrome'})
html = urlopen(req).read()
soup_tmp = BeautifulSoup(html, 'html.parser')
soup_tmp.find('p', 'addy')
# Out:
# <p class="addy">
# <em>$10. 2109 W. Chicago Ave., 773-772-0406, <a href="http://www.theoldoaktap.com/">theoldoaktap.com</a></em></p>

# %%
price_tmp = soup_tmp.find('p', 'addy').text
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave., 773-772-0406, theoldoaktap.com'

# %%
import re
re.split('.,', price_tmp)
# Out:
# ['\n$10. 2109 W. Chicago Ave', ' 773-772-040', ' theoldoaktap.com']

# %%
price_tmp = re.split('.,', price_tmp)[0]
price_tmp
# Out:
# '\n$10. 2109 W. Chicago Ave'

# %%
re.search("\d+\.(\d+)?", price_tmp)
# Out:
# <re.Match object; span=(2, 5), match='10.'>

# %%
tmp = re.search("\d+\.(\d+)?", price_tmp).group()
price_tmp[len(tmp) + 2:]
# Out:
# ' 2109 W. Chicago Ave'

# %%
import re
from tqdm import tqdm

price = []
address = []

for idx,row in tqdm(df.iterrows()):
    req = Request(row["URL"], headers={"user-agent":"Mozilla/5.0"})
    html = urlopen(req).read()
    soup_tmp = BeautifulSoup(html,"html.parser")
    gettings = soup_tmp.find("p","addy").get_text()
    price_tmp = re.split(".,",gettings)[0]
    tmp = re.search("\$\d+\.(\d+)?",price_tmp).group()
    price.append(tmp)
    address.append(price_tmp[len(tmp)+2:])
    print(idx)
# Out:
# 1it [00:01,  1.12s/it]
# 0
# 2it [00:02,  1.11s/it]
# 1
# 3it [00:03,  1.13s/it]
# 2
# 4it [00:04,  1.13s/it]
# 3
# 5it [00:06,  1.47s/it]
# 4
# 6it [00:07,  1.36s/it]
# 5
# 7it [00:11,  2.28s/it]
# 6
# 8it [00:14,  2.54s/it]
# 7
# 9it [00:17,  2.47s/it]
# 8
# 10it [00:18,  2.08s/it]
# 9
# 11it [00:19,  1.80s/it]
# 10
# 12it [00:22,  2.07s/it]
# 11
# 13it [00:25,  2.25s/it]
# 12
# 14it [00:27,  2.29s/it]
# 13
# 15it [00:28,  1.94s/it]
# 14
# 16it [00:29,  1.71s/it]
# 15
# 17it [00:33,  2.47s/it]
# 16
# 18it [00:36,  2.39s/it]
# 17
# 19it [00:38,  2.40s/it]
# 18
# 20it [00:39,  2.03s/it]
# 19
# 21it [00:41,  2.09s/it]
# 20
# 22it [00:46,  2.68s/it]
# 21
# 23it [00:47,  2.23s/it]
# 22
# 24it [00:51,  2.82s/it]
# 23
# 25it [00:55,  3.24s/it]
# 24
# 26it [00:59,  3.34s/it]
# 25
# 27it [01:02,  3.23s/it]
# 26
# 28it [01:03,  2.70s/it]
# 27
# 29it [01:05,  2.33s/it]
# 28
# 30it [01:06,  2.01s/it]
# 29
# 31it [01:07,  1.78s/it]
# 30
# 32it [01:08,  1.62s/it]
# 31
# 33it [01:11,  1.89s/it]
# 32
# 34it [01:14,  2.12s/it]
# 33
# 35it [01:15,  1.87s/it]
# 34
# 36it [01:17,  2.05s/it]
# 35
# 37it [01:19,  1.87s/it]
# 36
# 38it [01:21,  2.04s/it]
# 37
# 39it [01:22,  1.81s/it]
# 38
# 40it [01:25,  1.96s/it]
# 39
# 41it [01:27,  1.95s/it]
# 40
# 42it [01:29,  2.06s/it]
# 41
# 43it [01:30,  1.81s/it]
# 42
# 44it [01:32,  1.66s/it]
# 43
# 45it [01:34,  1.89s/it]
# 44
# 46it [01:37,  2.22s/it]
# 45
# 47it [01:41,  2.89s/it]
# 46
# 48it [01:46,  3.47s/it]
# 47
# 49it [01:50,  3.49s/it]
# 48
# 50it [01:51,  2.23s/it]
# 49

# %%
price, address
# Out:
# (['$10.',
#   '$9.',
#   '$9.50',
#   '$9.40',
#   '$10.',
#   '$7.25',
#   '$16.',
#   '$10.',
#   '$9.',
#   '$17.',
#   '$11.',
#   '$5.49',
#   '$14.',
#   '$10.',
#   '$13.',
#   '$4.50',
#   '$11.95',
#   '$11.50',
#   '$6.25',
#   '$15.',
#   '$5.',
#   '$6.',
#   '$8.',
#   '$5.99',
#   '$7.52',
#   '$11.95',
#   '$7.50',
#   '$12.95',
#   '$7.',
#   '$21.',
#   '$9.79',
#   '$9.75',
#   '$13.',
#   '$7.95',
#   '$9.',
#   '$9.',
#   '$8.',
#   '$8.',
#   '$7.',
#   '$6.',
#   '$7.25',
#   '$11.',
#   '$6.',
#   '$9.',
#   '$5.49',
#   '$8.',
#   '$6.50',
#   '$7.50',
#   '$8.75',
#   '$6.85'],
#  ['2109 W. Chicago Ave',
#   '800 W. Randolph St',
#   ' 445 N. Clark St',
#   ' 914 Noyes St',
#   '825 W. Fulton Mkt',
#   ' 100 E. Walton St',
#   '1639 S. Wabash Ave',
#   '2211 W. North Ave',
#   '3619 W. North Ave',
#   '3267 S. Halsted St',
#   '2537 N. Kedzie Blvd',
#   ' Multiple location',
#   '3124 N. Broadwa',
#   '3455 N. Southport Ave',
#   '2657 N. Kedzie Ave',
#   ' 1120 W. Grand Ave',
#   ' 1141 S. Jefferson St',
#   ' 333 E. Benton Pl',
#   ' 1411 N. Wells St',
#   '1747 N. Damen Ave',
#   '3209 W. Irving Park Rd',
#   'Multiple location',
#   '5347 N. Clark St',
#   ' 2954 W. Irving Park Rd',
#   ' Multiple location',
#   ' 191 Skokie Valley Rd',
#   ' Multiple location',
#   ' 1818 W. Wilson Ave',
#   '2517 W. Division St',
#   '218 W. Kinzie St',
#   ' Multiple location',
#   ' 1547 N. Wells St',
#   '415 N. Milwaukee Ave',
#   ' 1840 N. Damen Ave',
#   '1220 W. Webster Ave',
#   '5357 N. Ashland Ave',
#   '1834 W. Montrose Ave',
#   '615 N. State St',
#   'Multiple location',
#   '241 N. York Rd',
#   ' 1323 E. 57th St',
#   '655 Forest Ave',
#   'Hotel Lincol',
#   '100 S. Marion St',
#   ' 26 E. Congress Pkwy',
#   '2018 W. Chicago Ave',
#   ' 25 E. Delaware Pl',
#   ' 416 N. York St',
#   ' 65 E. Washington St',
#   ' 3351 N. Broadwa'])

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\administrator\.conda\envs\ds_study\lib\site-packages (4.66.2)
# Requirement already satisfied: colorama in c:\users\administrator\.conda\envs\ds_study\lib\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
len(price), len(address)
# Out:
# (50, 50)

# %%
df.tail(3)
# Out:
#     Rank             Cafe           Menu  \
# 47    48          Zenwich     Beef Curry
# 48    49  Toni Patisserie  Le Végétarien
# 49    50  Phoebe’s Bakery     The Gatsby
#
#                                                   URL
# 47  https://www.chicagomag.com/Chicago-Magazine/No...
# 48  https://www.chicagomag.com/Chicago-Magazine/No...
# 49  https://www.chicagomag.com/Chicago-Magazine/No...

# %%
df['Price'] = price
df['Address'] = address
df.tail()
# Out:
#     Rank                    Cafe                Menu  \
# 45    46                Chickpea               Kufta
# 46    47  The Goddess and Grocer  Debbie’s Egg Salad
# 47    48                 Zenwich          Beef Curry
# 48    49         Toni Patisserie       Le Végétarien
# 49    50         Phoebe’s Bakery          The Gatsby
#
#                                                   URL  Price  \
# 45  https://www.chicagomag.com/Chicago-Magazine/No...    $8.
# 46  https://www.chicagomag.com/Chicago-Magazine/No...  $6.50
# 47  https://www.chicagomag.com/Chicago-Magazine/No...  $7.50
# 48  https://www.chicagomag.com/Chicago-Magazine/No...  $8.75
# 49  https://www.chicagomag.com/Chicago-Magazine/No...  $6.85
#
#                  Address
# 45   2018 W. Chicago Ave
# 46     25 E. Delaware Pl
# 47        416 N. York St
# 48   65 E. Washington St
# 49       3351 N. Broadwa

# %%
df = df.loc[:, ['Rank', 'Cafe', 'Menu', 'Price', 'Address']]
df.head()
# Out:
#    Rank                    Cafe               Menu  Price              Address
# 0     1             Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 1     2               Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 2     3                    Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 3     4               Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 4     5  Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
df.set_index('Rank', inplace=True)
df.head()
# Out:
#                         Cafe               Menu  Price              Address
# Rank
# 1                Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
df.head()
# Out:
#                         Cafe               Menu  Price              Address
# Rank
# 1                Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt

# %%
df.to_csv('./data/03. best_sandwiches_list_chicago2.csv', sep=',', encoding='UTF-8')

# %%
pd.read_csv('./data/03. best_sandwiches_list_chicago2.csv', index_col=0)
# Out:
#                                  Cafe  \
# Rank
# 1                         Old Oak Tap
# 2                           Au Cheval
# 3                                Xoco
# 4                           Al’s Deli
# 5              Publican Quality Meats
# 6     Hendrickx Belgian Bread Crafter
# 7                              Acadia
# 8                   Birchwood Kitchen
# 9                      Cemitas Puebla
# 10                               Nana
# 11                          Lula Cafe
# 12                         Ricobene’s
# 13                       Frog n Snail
# 14                   Crosby’s Kitchen
# 15                    Longman & Eagle
# 16                               Bari
# 17                            Manny’s
# 18                             Eggy’s
# 19                      Old Jerusalem
# 20               Mindy’s HotChocolate
# 21                Olga’s Delicatessen
# 22       Dawali Mediterranean Kitchen
# 23                          Big Jones
# 24                            La Pane
# 25                           Pastoral
# 26                         Max’s Deli
# 27               Lucky’s Sandwich Co.
# 28                    City Provisions
# 29               Papa’s Cache Sabroso
# 30              Bavette’s Bar & Boeuf
# 31                   Hannah’s Bretzel
# 32                       La Fournette
# 33                     Paramount Room
# 34               Melt Sandwich Shoppe
# 35             Floriole Cafe & Bakery
# 36               First Slice Pie Café
# 37                            Troquet
# 38                         Grahamwich
# 39                     Saigon Sisters
# 40                     Rosalia’s Deli
# 41                     Z&H MarketCafe
# 42         Market House on the Square
# 43               Elaine’s Coffee Call
# 44        Marion Street Cheese Market
# 45                           Cafecito
# 46                           Chickpea
# 47             The Goddess and Grocer
# 48                            Zenwich
# 49                    Toni Patisserie
# 50                    Phoebe’s Bakery
#
#                                                 Menu   Price  \
# Rank
# 1                                                BLT    $10.
# 2                                      Fried Bologna     $9.
# 3                                  Woodland Mushroom   $9.50
# 4                                         Roast Beef   $9.40
# 5                                               PB&L    $10.
# 6                        Belgian Chicken Curry Salad   $7.25
# 7                                       Lobster Roll    $16.
# 8                                Smoked Salmon Salad    $10.
# 9                                    Atomica Cemitas     $9.
# 10    Grilled Laughing Bird Shrimp and Fried Po’ Boy    $17.
# 11                           Ham and Raclette Panino    $11.
# 12                                     Breaded Steak   $5.49
# 13                                       The Hawkeye    $14.
# 14                                       Chicken Dip    $10.
# 15                              Wild Boar Sloppy Joe    $13.
# 16                                      Meatball Sub   $4.50
# 17                                       Corned Beef  $11.95
# 18                                       Turkey Club  $11.50
# 19                                           Falafel   $6.25
# 20                                         Crab Cake    $15.
# 21                                 Chicken Schnitzel     $5.
# 22                                          Shawarma     $6.
# 23                           Toasted Pimiento Cheese     $8.
# 24                                 Vegetarian Panino   $5.99
# 25                                       Cali Chèvre   $7.52
# 26                                          Pastrami  $11.95
# 27                                         The Fredo   $7.50
# 28                                        Smoked Ham  $12.95
# 29                                          Jibarito     $7.
# 30                                  Shaved Prime Rib    $21.
# 31                   Serrano Ham and Manchego Cheese   $9.79
# 32                                        Tuna Salad   $9.75
# 33                                  Paramount Reuben    $13.
# 34                                      The Istanbul   $7.95
# 35                                            B.A.D.     $9.
# 36                        Duck Confit and Mozzarella     $9.
# 37                                   Croque Monsieur     $8.
# 38                                    Green Garbanzo     $8.
# 39                                     The Hen House     $7.
# 40                                    Tuscan Chicken     $6.
# 41                                        The Marty    $7.25
# 42                                         Whitefish    $11.
# 43            Oat Bread, Pecan Butter, and Fruit Jam     $6.
# 44                                  Cauliflower Melt     $9.
# 45                                            Cubana   $5.49
# 46                                             Kufta     $8.
# 47                                Debbie’s Egg Salad   $6.50
# 48                                        Beef Curry   $7.50
# 49                                     Le Végétarien   $8.75
# 50                                        The Gatsby   $6.85
#
#                       Address
# Rank
# 1         2109 W. Chicago Ave
# 2          800 W. Randolph St
# 3             445 N. Clark St
# 4                914 Noyes St
# 5           825 W. Fulton Mkt
# 6            100 E. Walton St
# 7          1639 S. Wabash Ave
# 8           2211 W. North Ave
# 9           3619 W. North Ave
# 10         3267 S. Halsted St
# 11        2537 N. Kedzie Blvd
# 12          Multiple location
# 13            3124 N. Broadwa
# 14      3455 N. Southport Ave
# 15         2657 N. Kedzie Ave
# 16          1120 W. Grand Ave
# 17       1141 S. Jefferson St
# 18           333 E. Benton Pl
# 19           1411 N. Wells St
# 20          1747 N. Damen Ave
# 21     3209 W. Irving Park Rd
# 22          Multiple location
# 23           5347 N. Clark St
# 24     2954 W. Irving Park Rd
# 25          Multiple location
# 26       191 Skokie Valley Rd
# 27          Multiple location
# 28         1818 W. Wilson Ave
# 29        2517 W. Division St
# 30           218 W. Kinzie St
# 31          Multiple location
# 32           1547 N. Wells St
# 33       415 N. Milwaukee Ave
# 34          1840 N. Damen Ave
# 35        1220 W. Webster Ave
# 36        5357 N. Ashland Ave
# 37       1834 W. Montrose Ave
# 38            615 N. State St
# 39          Multiple location
# 40             241 N. York Rd
# 41            1323 E. 57th St
# 42             655 Forest Ave
# 43               Hotel Lincol
# 44           100 S. Marion St
# 45        26 E. Congress Pkwy
# 46        2018 W. Chicago Ave
# 47          25 E. Delaware Pl
# 48             416 N. York St
# 49        65 E. Washington St
# 50            3351 N. Broadwa

# %%
import folium
import pandas as pd
import numpy as np
import googlemaps
from tqdm import tqdm

# %%
df = pd.read_csv('./data/03. best_sandwiches_list_chicago2.csv', index_col=0)
df.tail()
# Out:
#                         Cafe                Menu  Price               Address
# Rank
# 46                  Chickpea               Kufta    $8.   2018 W. Chicago Ave
# 47    The Goddess and Grocer  Debbie’s Egg Salad  $6.50     25 E. Delaware Pl
# 48                   Zenwich          Beef Curry  $7.50        416 N. York St
# 49           Toni Patisserie       Le Végétarien  $8.75   65 E. Washington St
# 50           Phoebe’s Bakery          The Gatsby  $6.85       3351 N. Broadwa

# %%
pd.read_csv('./data/03. best_sandwiches_list_chicago2.csv', index_col=0)
gmaps_key= 'AIzaSyC8taujTfRGPhNGndirCPBudEpks91MAKU'
gmaps = googlemaps.Client(key=gmaps_key)

# %%
lat = []
lng = []

for idx, row in tqdm(df.iterrows()):
    if not row["Address"]=="Multiple location":
        target_name = row["Address"] + "," + "Chicago"
        # print(target_name)
        gmaps_output = gmaps.geocode(target_name)
        location_output = gmaps_output[0].get("geometry")
        lat.append(location_output["location"]["lat"])
        lng.append(location_output["location"]["lng"])
        # location_output = gmaps_output[0]
    
    else:
        lat.append(np.nan)
        lng.append(np.nan)
# Out:
# 50it [00:04, 11.04it/s]

# %%
df['lat'] = lat
df['lng'] = lng
df.head()
# Out:
#                         Cafe               Menu  Price              Address  \
# Rank
# 1                Old Oak Tap                BLT   $10.  2109 W. Chicago Ave
# 2                  Au Cheval      Fried Bologna    $9.   800 W. Randolph St
# 3                       Xoco  Woodland Mushroom  $9.50      445 N. Clark St
# 4                  Al’s Deli         Roast Beef  $9.40         914 Noyes St
# 5     Publican Quality Meats               PB&L   $10.    825 W. Fulton Mkt
#
#             lat        lng
# Rank
# 1     41.895558 -87.679967
# 2     41.884639 -87.647590
# 3     41.890523 -87.630783
# 4     42.058322 -87.683748
# 5     41.886604 -87.648536

# %%
mapping = folium.Map(location=[41.896113,-87.677857],zoom_start=11)

for idx, row in df.iterrows():
    if not row["Address"] == "Multiple location":
        folium.Marker(
            location=[row["lat"],row["lng"]],
            popup=row["Cafe"],
            tooltip=row["Menu"],
            icon=folium.Icon(
                icon="coffee",
                prefix="fa"
            )
        ).add_to(mapping)
        
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19bd28983403c3a0fac5e4db16badb43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19bd28983403c3a0fac5e4db16badb43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19bd28983403c3a0fac5e4db16badb43 = L.map(
#                 &quot;map_19bd28983403c3a0fac5e4db16badb43&quot;,
#                 {
#                     center: [41.896113, -87.677857],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9f85cc17e9370e48c230e8aa8d438b79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9f85cc17e9370e48c230e8aa8d438b79.addTo(map_19bd28983403c3a0fac5e4db16badb43);
#
#
#             var marker_e1c563f68bcc080797c7532e6ae1f23a = L.marker(
#                 [41.8955577, -87.6799673],
#                 {}
#             ).addTo(map_19bd28983403c3a0fac5e4db16badb43);
#
#
#             var icon_2ec4a89be6e2a449a29ba0cc206f8523 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e1c563f68bcc080797c7532e6ae1f23a.setIcon(icon_2ec4a89be6e2a449a29ba0cc206f8523);
#
#
#         var popup_1944493df6d7e9bbe965522d129cc3ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_328fde1da1179b07e4bba0d23662b36f = $(`&lt;div id=&quot;html_328fde1da1179b07e4bba0d23662b36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Old Oak Tap&lt;/div&gt;`)[0];
#                 popup_1944493df6d7e9bbe965522d129cc3ec.setContent(html_328fde1da1179b07e4bba0d23662b36f);
#
#
#
#         marker_e1c563f68bcc080797c7532e6ae1f23a.bindPopup(popup_1944493df6d7e9bbe965522d129cc3ec)
#         ;
#
#
#
#
#             marker_e1c563f68bcc080797c7532e6ae1f23a.bindTooltip(
#                 `&lt;div&gt;
#                      BLT
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_19313c31db965db5446e5e1d273ce194 = L.marker(
#                 [41.8846392, -87.6475897],
#                 {}
#             ).addTo(map_19bd28983403c3a0fac5e4db16badb43);
#
#
#             var icon_0f0884017d6927444db2f46edd83b05a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_19313c31db965db5446e5e1d273ce194.setIcon(icon_0f0884017d6927444db2f46edd83b05a);
#
#
#         var popup_87929fc5284d15ced63fa315f377f326 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_279ec838945bb91b9b167aad82634520 = $(`&lt;div id=&quot;html_279ec838945bb91b9b167aad82634520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Au Cheval&lt;/div&gt;`)[0];
#                 popup_87929fc5284d15ced63fa315f377f326.setContent(html_279ec838945bb91b9b167aad82634520);
#
#
#
#         marker_19313c31db965db5446e5e1d273ce194.bindPopup(popup_87929fc5284d15ced63fa315f377f326)
#         ;
#
#
#
#
#             marker_19313c31db965db5446e5e1d273ce194.bindTooltip(
#                 `&lt;div&gt;
#                      Fried Bologna
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_767256b1c5c676736f59b5e854fdae48 = L.marker(
#                 [41.8905226, -87.6307834],
#                 {}
#             ).addTo(map_19bd28983403c3a0fac5e4db16badb43);
#
#
#             var icon_a6dd227929387be049874c2f0437c656 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;coffee&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_767256b1c5c676736f59b5e854fdae48.setIcon(icon_a6dd227929387be049874c2f0437c656);
#
#
#         var popup_b0bba8d6353e3b96f4299e7d303b342a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d0312bc7449c7b33a837184060ed4152 = $(`&lt;div id=&quot;html_d0312bc7449c7b33a837184060ed4152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Xoco&lt;/div&gt;`)[0];
#                 popup_b0bba8d6353e3b96f4299e7d303b342a.setContent(html_d0312bc7449c7b33a837184060ed4152);
#
#
#
#         marker_767256b1c5c676736f59b5e854fdae48.bindPopup(popup_b0bba8d6353e3b96f4299e7d303b342a)
#         ;
#
#
#
#
#             marker_7

# %%
df.tail()
# Out:
#                         Cafe                Menu  Price               Address
# Rank
# 46                  Chickpea               Kufta    $8.   2018 W. Chicago Ave
# 47    The Goddess and Grocer  Debbie’s Egg Salad  $6.50     25 E. Delaware Pl
# 48                   Zenwich          Beef Curry  $7.50        416 N. York St
# 49           Toni Patisserie       Le Végétarien  $8.75   65 E. Washington St
# 50           Phoebe’s Bakery          The Gatsby  $6.85       3351 N. Broadwa
