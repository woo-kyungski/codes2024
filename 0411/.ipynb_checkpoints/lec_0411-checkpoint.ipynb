# %%
from bs4 import BeautifulSoup

# %%
page = open('C:/Users/Administrator/Documents/ds_study/source_code/03.zerowk.html', 'r').read()
print(page)
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Very simple HTML Code by zerowk</title>
#     </head>
#     <body>
#         <div>
#             <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id= "pw-link">wkski</a>
#                 <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" target="_blink" id="py-link">Python</a>
#                 </p>
#             </p>
#         </div>
#         <p class = "outer-text first-item" id="second">
#             <b>Data Science is funny.</b>
#         </p>
#         <p class="outer-text">
#             <i>All I need is Love</i>
#         </p>
#     </body>
#
# </html>

# %%
soup = BeautifulSoup(page, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Very simple HTML Code by zerowk</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>Data Science is funny.</b>
# </p>
# <p class="outer-text">
# <i>All I need is Love</i>
# </p>
# </body>
# </html>

# %%
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify()) #들여쓰기까지 표현
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very simple HTML Code by zerowk
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happ zerowk.
#     <a href="https://blog.naver.com/wookyung15" id="pw-link">
#      wkski
#     </a>
#     <p class="inner-text second-item">
#      Happy Data Science.
#      <a href="https://www.python.org" id="py-link" target="_blink">
#       Python
#      </a>
#     </p>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <i>
#     All I need is Love
#    </i>
#   </p>
#  </body>
# </html>

# %%
soup.head
# Out:
# <head>
# <title>Very simple HTML Code by zerowk</title>
# </head>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>Data Science is funny.</b>
# </p>
# <p class="outer-text">
# <i>All I need is Love</i>
# </p>
# </body>

# %%
soup.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>
# </p>

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>
# </p>

# %%
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happ zerowk.
#                  <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
#  <p class="inner-text second-item">
#                      Happy Data Science.
#                      <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
#  </p>
#  </p>,
#  <p class="inner-text second-item">
#                      Happy Data Science.
#                      <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>Data Science is funny.</b>
#  </p>,
#  <p class="outer-text">
#  <i>All I need is Love</i>
#  </p>]

# %%
soup.find('p', class_='inner-text second-item')
# Out:
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>

# %%
soup.find('p', {'class':'outer-text first-item'})
# Out:
# <p class="outer-text first-item" id="second">
# <b>Data Science is funny.</b>
# </p>

# %%
soup.find('p', {'class':'outer-text first-item'}).text.strip()
# Out:
# 'Data Science is funny.'

# %%
soup.find('p', {'class':'inner-text first-item', "id":"first"})
# Out:
# <p class="inner-text first-item" id="first">
#                 Happ zerowk.
#                 <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
# <p class="inner-text second-item">
#                     Happy Data Science.
#                     <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
# </p>
# </p>

# %%
#list 형태로 반환
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happ zerowk.
#                  <a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>
#  <p class="inner-text second-item">
#                      Happy Data Science.
#                      <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
#  </p>
#  </p>,
#  <p class="inner-text second-item">
#                      Happy Data Science.
#                      <a href="https://www.python.org" id="py-link" target="_blink">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>Data Science is funny.</b>
#  </p>,
#  <p class="outer-text">
#  <i>All I need is Love</i>
#  </p>]

# %%
soup.find_all(id='pw-link')[0].text
# Out:
# 'wkski'

# %%
for each_tag in soup.find_all('p'):
    print('=' * 50)
    print(each_tag.text)
# Out:
# ...
#
#                 Happ zerowk.
#                 wkski
#
#                     Happy Data Science.
#                     Python
#
#
# ...
#
#                     Happy Data Science.
#                     Python
#
# ...
#
# Data Science is funny.
#
# ...
#
# All I need is Love

# %%
links = soup.find_all('a')
links
# Out:
# [<a href="https://blog.naver.com/wookyung15" id="pw-link">wkski</a>,
#  <a href="https://www.python.org" id="py-link" target="_blink">Python</a>]

# %%
for each in links:
    href = each.get('href')
    text = each.get_text()
    print(text + ' => ' + href)
# Out:
# wkski => https://blog.naver.com/wookyung15
# Python => https://www.python.org

# %%
#Beatifulsoup 1-1
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/marketindex/index.naver'
page = urlopen(url)
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240411105708/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240411105708/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        ШЏРќ АэНУ ШЏРВ
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
page.status #http 상태 코드
# Out:
# 200

# %%
soup.find_all('span', 'value')
# Out:
# [<span class="value">1,368.00</span>,
#  <span class="value">893.39</span>,
#  <span class="value">1,468.00</span>,
#  <span class="value">188.59</span>,
#  <span class="value">153.2800</span>,
#  <span class="value">1.0705</span>,
#  <span class="value">1.2520</span>,
#  <span class="value">105.0300</span>,
#  <span class="value">86.21</span>,
#  <span class="value">1679.99</span>,
#  <span class="value">2348.4</span>,
#  <span class="value">102916.28</span>]

# %%
len(soup.find_all('span', 'value'))
# Out:
# 12

# %%
soup.find_all('span', class_='value')
# Out:
# [<span class="value">1,368.00</span>,
#  <span class="value">893.39</span>,
#  <span class="value">1,468.00</span>,
#  <span class="value">188.59</span>,
#  <span class="value">153.2800</span>,
#  <span class="value">1.0705</span>,
#  <span class="value">1.2520</span>,
#  <span class="value">105.0300</span>,
#  <span class="value">86.21</span>,
#  <span class="value">1679.99</span>,
#  <span class="value">2348.4</span>,
#  <span class="value">102916.28</span>]

# %%
soup.find_all('span', {'class':'value'})
# Out:
# [<span class="value">1,368.00</span>,
#  <span class="value">893.39</span>,
#  <span class="value">1,468.00</span>,
#  <span class="value">188.59</span>,
#  <span class="value">153.2800</span>,
#  <span class="value">1.0705</span>,
#  <span class="value">1.2520</span>,
#  <span class="value">105.0300</span>,
#  <span class="value">86.21</span>,
#  <span class="value">1679.99</span>,
#  <span class="value">2348.4</span>,
#  <span class="value">102916.28</span>]

# %%
soup.find_all('span', {'class':'value'})[0]
# Out:
# <span class="value">1,368.00</span>

# %%
soup.find_all('span', {'class':'value'})[0].text
# Out:
# '1,368.00'

# %%
soup.find_all('span', {'class':'value'})[0].string
# Out:
# '1,368.00'

# %%
soup.find_all('span', {'class':'value'})[0].get_text()
# Out:
# '1,368.00'

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/marketindex/index.naver'
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.text,"html.parser")
print(soup.prettify())
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240411105708/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript">
# </script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20240411105708/js/jindo.1.5.3.element-text-patch.js" type="text/javascript">
# </script>
# <div id="container" style="padding-bottom:0px;">
#  <div class="market_include">
#   <div class="market_data">
#    <div class="market1">
#     <div class="title">
#      <h2 class="h_market1">
#       <span>
#        환전 고시 환율
#       </span>
#      </h2>
#     </div>
#     <!-- data -->
#     <div class="data">
#      <ul class="data_lst" id="exchangeList">
#       <li class="on">
#        <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# ...

# %%
soup.find_all('li', '')
# Out:
# [<li class="on">
#  <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#  <div class="head_info point_up">
#  <span class="value">1,368.00</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change">3.00</span>
#  <span class="blind">상승</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2024.04.11 23:58</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">239</span>회</span>
#  </div>
#  </li>,
#  <li class="">
# ...

# %%
exchangelist = soup.select('li')
len(exchangelist)
# Out:
# 36

# %%
exchangeList = soup.select("#exchangeList > li") # id / . class
len(exchangeList), exchangeList
# Out:
# (4,
#  [<li class="on">
#   <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#   <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#   <div class="head_info point_up">
#   <span class="value">1,368.00</span>
#   <span class="txt_krw"><span class="blind">원</span></span>
#   <span class="change">3.00</span>
#   <span class="blind">상승</span>
#   </div>
#   </a>
#   <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#   <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#   </a>
#   <div class="graph_info">
#   <span class="time">2024.04.11 23:58</span>
#   <span class="source">하나은행 기준</span>
#   <span class="count">고시회차<span class="num">239</span>회</span>
#   </div>
#   </li>,
#   <li class="">
# ...

# %%
title = exchangeList[0].select_one(".h_lst").text
exchange = exchangeList[0].select_one(".value").text
change = exchangeList[0].select_one(".change").text
updown = exchangeList[0].select_one("div.head_info.point_up > .blind").text
# 만약 태그에 띄어쓰기가 있다면 중간에 .을 찍어준다.
# >이 있다면 바로 밑 하위이고, >이 없다면 자손이다.
#link
title,exchange,updown
# Out:
# ('미국 USD', '1,368.00', '상승')

# %%
findmethod = soup.find_all('ul', id='exchangeList')
findmethod
# Out:
# [<ul class="data_lst" id="exchangeList">
#  <li class="on">
#  <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
#  <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
#  <div class="head_info point_up">
#  <span class="value">1,368.00</span>
#  <span class="txt_krw"><span class="blind">원</span></span>
#  <span class="change">3.00</span>
#  <span class="blind">상승</span>
#  </div>
#  </a>
#  <a class="graph_img" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdc', '', '', event);">
#  <img alt="" height="153" src="https://ssl.pstatic.net/imgfinance/chart/marketindex/FX_USDKRW.png" width="295"/>
#  </a>
#  <div class="graph_info">
#  <span class="time">2024.04.11 23:58</span>
#  <span class="source">하나은행 기준</span>
#  <span class="count">고시회차<span class="num">239</span>회</span>
#  </div>
#  </li>
#  <li class="">
# ...

# %%
findmethod[0].find_all('span', 'value')
# Out:
# [<span class="value">1,368.00</span>,
#  <span class="value">893.39</span>,
#  <span class="value">1,468.00</span>,
#  <span class="value">188.59</span>]

# %%
baseUrl = "https://finance.naver.com"
baseUrl + exchangeList[0].select_one("a").get("href")
# Out:
# 'https://finance.naver.com/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW'

# %%
# 4개 데이터 수집
import pandas as pd
import openpyxl

exchange_datas = []
baseUrl = "https://finance.naver.com"

for item in exchangeList:
    try:
        data = {
            "title":item.select_one(".h_lst").text,
            "exchange":item.select_one(".value").text,
            "change":item.select_one(".change").text,
            "updown":item.select_one("div.head_info.point_up > .blind").get_text(),
            "link": baseUrl + item.select_one("a").get("href")
        }
    except:
        data = {
        "title":item.select_one(".h_lst").text,
        "exchange":item.select_one(".value").text,
        "change":item.select_one(".change").text,
        "updown":"상승",
        "link": baseUrl + item.select_one("a").get("href")
    }
    exchange_datas.append(data)
    
df = pd.DataFrame(exchange_datas)
df, df.to_excel("./naverFinance.xlsx")

# 유럽의 updown값이 None으로 뜨는 오류가 발생해서 try~except 예외문 사용
# Out:
# (          title  exchange change updown  \
#  0        미국 USD  1,368.00   3.00     상승
#  1  일본 JPY(100엔)    893.39   1.03     상승
#  2      유럽연합 EUR  1,468.00   1.44     상승
#  3        중국 CNY    188.59   0.63     상승
#
#                                                  link
#  0  https://finance.naver.com/marketindex/exchange...
#  1  https://finance.naver.com/marketindex/exchange...
#  2  https://finance.naver.com/marketindex/exchange...
#  3  https://finance.naver.com/marketindex/exchange...  ,
#  None)
