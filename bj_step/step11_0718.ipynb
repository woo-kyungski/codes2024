# %% [markdown]
# # Step 11 시간 복잡도 단계

# %% [markdown]
# 단계	문제 번호	제목	정보	정답	제출	정답 비율 https://www.acmicpc.net/step/53

# %% [markdown]
# 1	24262	 알고리즘 수업 - 알고리즘의 수행 시간 1		16877	22513	75.985% https://www.acmicpc.net/problem/24262

# %%
n = int(input())
print(1)
print(0)
# Out:
# 1
# 1
# 0

# %% [markdown]
# 2	24263	 알고리즘 수업 - 알고리즘의 수행 시간 2		13585	17204	79.617% https://www.acmicpc.net/problem/24263

# %%
n = int(input())
print(n)
print(1)

# %% [markdown]
# 3	24264	 알고리즘 수업 - 알고리즘의 수행 시간 3		12314	23931	51.589% https://www.acmicpc.net/problem/24264

# %%
n = int(input())
print(n * n)
print(2)
# Out:
# 7
# 49
# 2

# %% [markdown]
# 4	24265	 알고리즘 수업 - 알고리즘의 수행 시간 4		11969	23524	51.230% https://www.acmicpc.net/problem/24265

# %%
n = int(input())
print(int(n * (n - 1) - (n-1) * n / 2))
print(2)

# %% [markdown]
# 5	24266	 알고리즘 수업 - 알고리즘의 수행 시간 5		11319	15529	73.722% https://www.acmicpc.net/problem/24266

# %%
n = int(input())
print(n ** 3)
print(3)
# Out:
# 7
# 343
# 3

# %% [markdown]
# 6	24267	 알고리즘 수업 - 알고리즘의 수행 시간 6		10767	22156	49.662% https://www.acmicpc.net/problem/24267

# %%
n = int(input())
print(((n-2)*(n-1)*(2*n-3)+3*(n-1)*(n-2))//12)
print(3)
# Out:
# 7
# 35
# 3

# %% [markdown]
# 7	24313	 알고리즘 수업 - 점근적 표기 1		10462	30728	33.795% https://www.acmicpc.net/problem/24313

# %%
O(g(n)) = {f(n) | 모든 n ≥ n0에 대하여 f(n) ≤ c × g(n)인 양의 상수 c와 n0가 존재한다}

이 정의는 실제 O-표기법(https://en.wikipedia.org/wiki/Big_O_notation)과 다를 수 있다.

함수 f(n) = a1n + a0, 양의 정수 c, n0가 주어질 경우 O(n) 정의를 만족하는지 알아보자.

# %%
a_one, a_zero = map(int, input().split(' '))
c = int(input())
n_zero = int(input())

if ((a_one * n_zero + a_zero <= c * n_zero)) and (a_one <= c):
    print(1)
    
else:
    print(0)
