# %%
def add(n1, n2):
    print(f'덧셈 결과: {n1 + n2}')

def sub(n1, n2):
    print(f'덧셈 결과: {n1 - n2}')

def mul(n1, n2):
    print(f'덧셈 결과: {n1 * n2}')

def div(n1, n2):
    print(f'덧셈 결과: {n1 / n2}')
