# %%
#팩토리얼 재귀함수로 구현하기
def recursionFun(n):
    if n == 1:
        return n

    return n * recursionFun(n-1)

input_num = int(input())
print(recursionFun(input_num))
# Out:
#  5
# 120

# %%
def getPermutationCnt(n, r, logprint = True):

    result = 1
    for n in range(n, n-rm -1):
        result *= n

    return result

# %%
def getPermutationCnt(n, r, logprint = True):

    result = 1
    for n in range(n, n-r -1):
        result *= n

    return result

from itertools import permutations as pt

numN = int(input('numN 입력: '))
numR = int(input('numR 입력: '))

print(f'{numN}P{numR} : {pt(getPermutationCnt(numN, numR, logprint=False))}')
# Out:
# numN 입력:  10
# numR 입력:  3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 14
#      11 numN = int(input('numN 입력: '))
#      12 numR = int(input('numR 입력: '))
# ---> 14 print(f'{numN}P{numR} : {pt(getPermutationCnt(numN, numR, logprint=False))}')
#
# TypeError: 'int' object is not iterable

# %%
from itertools import permutations

# %%
print(f'{numN}P{numR} : {pt.getPermutationCnt(numN,numR,logPrint=False)}')
[출처] 231129 python module 모듈 문제 풀이|작성자 임다경
