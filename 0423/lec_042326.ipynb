# %%
pip list
# Out:
# Package                   VersionNote: you may need to restart the kernel to use updated packages.
#
# ------------------------- ---------------
# anyio                     4.2.0
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.0.5
# async-lru                 2.0.4
# attrs                     23.2.0
# Babel                     2.11.0
# backcall                  0.2.0
# beautifulsoup4            4.12.2
# bleach                    4.1.0
# Bottleneck                1.3.5
# branca                    0.7.1
# Brotli                    1.0.9
# bs4                       0.0.2
# by                        0.0.4
# certifi                   2023.11.17
# cffi                      1.16.0
# charset-normalizer        2.0.4
# colorama                  0.4.6
# comm                      0.1.2
# contourpy                 1.0.5
# cryptography              41.0.7
# cycler                    0.11.0
# ...

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome() #Selenium 4버전 이상에서는 크롬 드라이버를 따로 설치하지 않아도 된다!
driver.get('https://www.naver.com')
driver.quit()

# %%
driver = webdriver.Chrome() #Selenium 4버전 이상에서는 크롬 드라이버를 따로 설치하지 않아도 된다!
driver.get('https://pinkwink.kr/')

# %%
driver.get_window_size()
# Out:
# {'width': 1050, 'height': 718}

# %%
driver.get_window_position()
# Out:
# {'x': 10, 'y': 10}

# %%
driver.get_window_rect()
# Out:
# {'height': 718, 'width': 1050, 'x': 10, 'y': 10}

# %%
driver.execute_script('return document.body.scrollHeight')
# Out:
# 5925

# %%
driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')

# %%
driver.execute_script('window.scrollTo(0, 0)')

# %%
driver.save_screenshot('./last_height.png')
# Out:
# True

# %%
from selenium.webdriver.common.by import By
from selenium.webdriver import ActionChains

some_tag = driver.find_element(By.XPATH, '//*[@id="header"]/div[2]/input')
action = ActionChains(driver)
action.move_to_element(some_tag).perform()
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# Cell In[12], line 6
#       4 some_tag = driver.find_element(By.XPATH, '//*[@id="header"]/div[2]/input')
#       5 action = ActionChains(driver)
# ----> 6 action.move_to_element(some_tag).perform()
#
# File ~\.conda\envs\ds_study\lib\site-packages\selenium\webdriver\common\action_chains.py:94, in ActionChains.perform(self)
#      92 def perform(self) -> None:
#      93     """Performs all stored actions."""
# ---> 94     self.w3c_actions.perform()
#
# File ~\.conda\envs\ds_study\lib\site-packages\selenium\webdriver\common\actions\action_builder.py:96, in ActionBuilder.perform(self)
#      94         enc["actions"].append(encoded)
#      95         device.actions = []
# ---> 96 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# ...

# %%
sec_tag = driver.find_element(By.CLASS_NAME, "search")
sec_tags = driver.execute_script("arguments[0].click();", sec_tag)

# %%
some_tag.clear()
some_tag.send_keys('python')

# %%
driver.set_window_size(500, 300)

# %%
driver.maximize_window()

# %%
driver.minimize_window()

# %%
xpath = '//*[@id="header"]/div[2]/button'
some_tag = driver.find_element(By.XPATH, xpath)
some_tag.click()

# %%
driver.back()

# %%
driver.forward()

# %%
driver.page_source
# Out:
# '<html lang="ko"><head>\n                <script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202404230101/show_ads_impl_fy2021.js?bust=31083084"></script><script type="text/javascript">if (!window.T) { window.T = {} }\nwindow.T.config = {"TOP_SSL_URL":"https://www.tistory.com","PREVIEW":false,"ROLE":"guest","PREV_PAGE":"","NEXT_PAGE":"","BLOG":{"id":371175,"name":"pinkwink","title":"PinkWink","isDormancy":false,"nickName":"PinkWink","status":"open","profileStatus":"normal"},"NEED_COMMENT_LOGIN":false,"COMMENT_LOGIN_CONFIRM_MESSAGE":"","LOGIN_URL":"https://www.tistory.com/auth/login/?redirectUrl=https://pinkwink.kr/search/python","DEFAULT_URL":"https://pinkwink.kr","USER":{"name":null,"homepage":null,"id":0,"profileImage":null},"SUBSCRIPTION":{"status":"none","isConnected":false,"isPending":false,"isWait":false,"isProcessing":false,"isNone":true},"IS_LOGIN":false,"HAS_BLOG":false,"IS_SUPPORT":false,"TOP_URL":"http://www.tistory.com","JOIN_URL":"https://www.ti
# ...

# %%
from bs4 import BeautifulSoup

req = driver.page_source
soup = BeautifulSoup(req, 'html.parser')

# %%
driver.quit()
